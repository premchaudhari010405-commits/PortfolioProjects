# %%
# import libraries 

from bs4 import BeautifulSoup
import requests
import time 
import datetime

import smtplib

# %%
# Connect to Website and pull in data

URL = 'https://www.amazon.in/CreativiT-Unisex-Regular-Customized-RN_CTZ_Black/dp/B0FBX1521B/ref=sr_1_1_sspa?crid=3L2MLFS1T06Q0&dib=eyJ2IjoiMSJ9.pNCJ6WaE3Ly8NR_9kLXccv0mv9b_Pg2akKNE-OOAmJvSlSqRYV0I4gtzTSverKsHb-MG4K2lcu2RIvH6RILLm8IGxfxnu2KgOo8Fw5dLZ03HueO-dBOaQGV0h-2_idjY_yqScIw0WtD2ZoHR2B95hBPc8mrKC0wCEAZ8MQ5RAxufrtEGjA1_AS3r3crbDsfHxTs7L57Xbo1QS2_nG4QqJk_sZS4NaqObNu_hat5gZJYISvlWKNq4_cTevyBRROKRRSVvxnRimkVhLYWKFVY0s_bwxWf-CWa2N8M8E3Jm4Ts.iMx8uoFl1kiNTjEbODgTiC0CC6d313Naw-yJYICm6T0&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1784270757&sprefix=data%2Banalyst%2Caps%2C559&sr=8-1-spons&aref=a5LowoYAWc&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text()

price = soup2.find(id='apex-pricetopay-accessibility-label').get_text()


print(title)
print(price)
# Out:
#                  CreativiT Unisex Men/Women Regular Fit Customized Tshirt | Casual Half Sleeve Round Neck | 100% Cotton with a High Thread Count
#
#
#                   ₹397.00 with 50 percent savings

# %%
# Create a Timestamp for your output to track when data was collected

import datetime

today = datetime.date.today()

print(today)
# Out:
# 2026-07-17

# %%
# Clean up the data a little bit

price = price.strip()[1:]
title = title.strip()

print(title)
print(price)
# Out:
# CreativiT Unisex Men/Women Regular Fit Customized Tshirt | Casual Half Sleeve Round Neck | 100% Cotton with a High Thread Count
# 397.00 with 50 percent savings

# %%
# Create CSV and write headers and data into the file

import csv 

header = ['Title', 'Price', 'Date']
data = [title, price, today]


#with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    #writer = csv.writer(f)
    #writer.writerow(header)
    #writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\premc\AmazonWebScraperDataset.csv')

print(df)

# %%
#Now we are appending data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    
    URL = 'https://www.amazon.in/CreativiT-Unisex-Regular-Customized-RN_CTZ_Black/dp/B0FBX1521B/ref=sr_1_1_sspa?crid=3L2MLFS1T06Q0&dib=eyJ2IjoiMSJ9.pNCJ6WaE3Ly8NR_9kLXccv0mv9b_Pg2akKNE-OOAmJvSlSqRYV0I4gtzTSverKsHb-MG4K2lcu2RIvH6RILLm8IGxfxnu2KgOo8Fw5dLZ03HueO-dBOaQGV0h-2_idjY_yqScIw0WtD2ZoHR2B95hBPc8mrKC0wCEAZ8MQ5RAxufrtEGjA1_AS3r3crbDsfHxTs7L57Xbo1QS2_nG4QqJk_sZS4NaqObNu_hat5gZJYISvlWKNq4_cTevyBRROKRRSVvxnRimkVhLYWKFVY0s_bwxWf-CWa2N8M8E3Jm4Ts.iMx8uoFl1kiNTjEbODgTiC0CC6d313Naw-yJYICm6T0&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1784270757&sprefix=data%2Banalyst%2Caps%2C559&sr=8-1-spons&aref=a5LowoYAWc&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser") 

    title = soup2.find(id='productTitle').get_text()

    price = soup2.find(id='apex-pricetopay-accessibility-label').get_text()

    price = price.strip()[1:]
    title = title.strip()

    import datetime

    today = datetime.date.today()

    import csv 

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
      writer = csv.writer(f)
      writer.writerow(data)

# %%
# Runs check_price after a set time and inputs data into your CSV
while(True):
  check_price()
  time.sleep(86400)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\premc\AmazonWebScraperDataset.csv')

print(df)

# %%
def send_mail():
    server = smtplib.SMTP_SSL('asgunique04.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('asgunique04@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Shirt you want is below 350! Now is your chance to buy!"
    body = "Prem, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.in/CreativiT-Unisex-Regular-Customized-RN_CTZ_Black/dp/B0FBX1521B/ref=sr_1_1_sspa?crid=3L2MLFS1T06Q0&dib=eyJ2IjoiMSJ9.pNCJ6WaE3Ly8NR_9kLXccv0mv9b_Pg2akKNE-OOAmJvSlSqRYV0I4gtzTSverKsHb-MG4K2lcu2RIvH6RILLm8IGxfxnu2KgOo8Fw5dLZ03HueO-dBOaQGV0h-2_idjY_yqScIw0WtD2ZoHR2B95hBPc8mrKC0wCEAZ8MQ5RAxufrtEGjA1_AS3r3crbDsfHxTs7L57Xbo1QS2_nG4QqJk_sZS4NaqObNu_hat5gZJYISvlWKNq4_cTevyBRROKRRSVvxnRimkVhLYWKFVY0s_bwxWf-CWa2N8M8E3Jm4Ts.iMx8uoFl1kiNTjEbODgTiC0CC6d313Naw-yJYICm6T0&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1784270757&sprefix=data%2Banalyst%2Caps%2C559&sr=8-1-spons&aref=a5LowoYAWc&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'asgunique04@gmail.com',
        msg
     
    )
